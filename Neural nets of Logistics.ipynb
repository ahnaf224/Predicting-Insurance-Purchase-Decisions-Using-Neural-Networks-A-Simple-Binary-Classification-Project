# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("/Users/ahnafchowdhury/Downloads/Logis.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    46                 0
# 4    52                 0
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 1
# 13   29                 0
# 14   21                 0
# 15   18                 0
# 16   55                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 1
# 22   40                 1
# 23   45                 1
# 24   41                 1
# 25   54                 1
# 26   23                 0

# %%
X = df[['age']].values  # Extract input columns
y = df[['bought_insurance']].values  # Extract target/output column

# Step 3: Define the neural network
model = Sequential([
    Dense(60, activation='relu', input_dim=1),  # 3 input features
    Dense(30, activation='relu'),   # Hidden layer with 5 neurons
    Dense(1, activation='sigmoid'),
                                   # Output layer
])

# Step 4: Compile the model
model.compile(optimizer='adam', loss='mse',metrics=['accuracy'])  # Mean Squared Error for regression

# Step 5: Train the model
history = model.fit(X, y, epochs=700, verbose=1)
# Out:
# Epoch 1/700
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.5185 - loss: 0.2618
# Epoch 2/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4815 - loss: 0.2395
# Epoch 3/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4815 - loss: 0.2489
# Epoch 4/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4815 - loss: 0.2513
# Epoch 5/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4815 - loss: 0.2454
# Epoch 6/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4815 - loss: 0.2392
# Epoch 7/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4815 - loss: 0.2389
# Epoch 8/700
# ...

# %%
c=model.predict(np.array([[25]]))
c
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# array([[0.23189628]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.show()
